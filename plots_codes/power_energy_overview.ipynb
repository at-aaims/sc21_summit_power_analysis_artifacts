# %%
# !conda install -y -c conda-forge pyarrow python-snappy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /autofs/nccs-svm1_home1/25amk/gears/.gears.andes
#
#   added / updated specs:
#     - pyarrow
#     - python-snappy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20200225.2      |       he1b5a44_2         915 KB  conda-forge
#     arrow-cpp-3.0.0            |   py38hced866c_0         6.5 MB
#     boost-cpp-1.69.0           |    h11c811c_1000        20.7 MB  conda-forge
#     brotli-1.0.9               |       h9c3ff4c_4         389 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     double-conversion-3.1.5    |       he1b5a44_2          85 KB  conda-forge
#     gflags-2.2.2               |    he1b5a44_1004         114 KB  conda-forge
#     glog-0.4.0                 |       h49b9bf7_3         104 KB  conda-forge
#     grpc-cpp-1.28.1            |       h8e748ff_2         4.0 MB  conda-forge
#     icu-58.2                   |    hf484d3e_1000        22.6 MB  conda-forge
#     libboost-1.73.0            |      h3ff78a5_11        13.9 MB
#     libevent-2.1.10            |       hcdb4288_3         1.1 MB  conda-forge
#     libgcc-7.2.0               |       h69d50b8_2         304 KB  conda-forge
#     libprotobuf-3.11.4         |       h8b12597_0         4.8 MB  conda-forge
#     libthrift-0.13.0           |       h5aa387f_6         3.3 MB  conda-forge
#     nodejs-6.13.1              |                0        11.9 MB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     orc-1.6.5                  |       h973521d_1         587 KB
#     pyarrow-3.0.0              |   py38he0739d4_3         1.9 MB
#     python-snappy-0.6.0        |   py38h49bdff1_0          31 KB  conda-forge
#     re2-2020.11.01             |       h58526e2_0         226 KB  conda-forge
#     uriparser-0.9.3            |       he1b5a44_1          49 KB  conda-forge
#     utf8proc-2.6.1             |       h27cfd23_0         308 KB
#     zstd-1.4.5                 |       h9ceee32_0         619 KB
#     ------------------------------------------------------------
#                                            Total:        96.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   abseil-cpp         conda-forge/linux-64::abseil-cpp-20200225.2-he1b5a44_2
#   arrow-cpp          pkgs/main/linux-64::arrow-cpp-3.0.0-py38hced866c_0
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.69.0-h11c811c_1000
#   brotli             conda-forge/linux-64::brotli-1.0.9-h9c3ff4c_4
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.17.1-h7f98852_1
#   double-conversion  conda-forge/linux-64::double-conversion-3.1.5-he1b5a44_2
#   gflags             conda-forge/linux-64::gflags-2.2.2-he1b5a44_1004
#   glog               conda-forge/linux-64::glog-0.4.0-h49b9bf7_3
#   grpc-cpp           conda-forge/linux-64::grpc-cpp-1.28.1-h8e748ff_2
#   libboost           pkgs/main/linux-64::libboost-1.73.0-h3ff78a5_11
#   libevent           conda-forge/linux-64::libevent-2.1.10-hcdb4288_3
#   libgcc             conda-forge/linux-64::libgcc-7.2.0-h69d50b8_2
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.11.4-h8b12597_0
#   libthrift          conda-forge/linux-64::libthrift-0.13.0-h5aa387f_6
#   orc                pkgs/main/linux-64::orc-1.6.5-h973521d_1
#   pyarrow            pkgs/main/linux-64::pyarrow-3.0.0-py38he0739d4_3
#   re2                conda-forge/linux-64::re2-2020.11.01-h58526e2_0
#   uriparser          conda-forge/linux-64::uriparser-0.9.3-he1b5a44_1
#   utf8proc           pkgs/main/linux-64::utf8proc-2.6.1-h27cfd23_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1k-h7f98852_0
#   python-snappy                        0.5.4-py38hd7b2518_3 --> 0.6.0-py38h49bdff1_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   zstd                   conda-forge::zstd-1.4.9-ha95c52a_0 --> pkgs/main::zstd-1.4.5-h9ceee32_0
#
# The following packages will be DOWNGRADED:
#
#   icu                                       68.1-h58526e2_0 --> 58.2-hf484d3e_1000
#   nodejs                                 15.12.0-h92b4a50_0 --> 6.13.1-0
#
#
#
# Downloading and Extracting Packages
# gflags-2.2.2         | 114 KB    | ##################################### | 100%
# double-conversion-3. | 85 KB     | ##################################### | 100%
# zstd-1.4.5           | 619 KB    | ##################################### | 100%
# grpc-cpp-1.28.1      | 4.0 MB    | ##################################### | 100%
# openssl-1.1.1k       | 2.1 MB    | ##################################### | 100%
# libevent-2.1.10      | 1.1 MB    | ##################################### | 100%
# libthrift-0.13.0     | 3.3 MB    | ##################################### | 100%
# python-snappy-0.6.0  | 31 KB     | ##################################### | 100%
# bzip2-1.0.8          | 484 KB    | ##################################### | 100%
# uriparser-0.9.3      | 49 KB     | ##################################### | 100%
# libprotobuf-3.11.4   | 4.8 MB    | ##################################### | 100%
# orc-1.6.5            | 587 KB    | ##################################### | 100%
# boost-cpp-1.69.0     | 20.7 MB   | ##################################### | 100%
# re2-2020.11.01       | 226 KB    | ##################################### | 100%
# icu-58.2             | 22.6 MB   | ##################################### | 100%
# brotli-1.0.9         | 389 KB    | ##################################### | 100%
# pyarrow-3.0.0        | 1.9 MB    | ##################################### | 100%
# glog-0.4.0           | 104 KB    | ##################################### | 100%
# c-ares-1.17.1        | 109 KB    | ##################################### | 100%
# abseil-cpp-20200225. | 915 KB    | ##################################### | 100%
# nodejs-6.13.1        | 11.9 MB   | ##################################### | 100%
# arrow-cpp-3.0.0      | 6.5 MB    | ##################################### | 100%
# libgcc-7.2.0         | 304 KB    | ##################################### | 100%
# utf8proc-2.6.1       | 308 KB    | ##################################### | 100%
# libboost-1.73.0      | 13.9 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import matplotlib as mpl

# %% [markdown]
# ## Summit cooling plant data

# %%
COOLING_PATH = "/gpfs/alpine/proj-shared/stf218/data/lake/summit_cooling_plant"

cooling_file = glob.glob(COOLING_PATH + "/*.parquet")

# %%
cooling_df = pd.read_parquet(cooling_file[0], engine="pyarrow").sort_index()

# %%
cooling_df.head(5)
# Out:
#                          mtwst  cep_mtw_tons  almk100_leakdetection_alarm  \
# timestamp_utc
# 2020-01-31 21:15:04  70.910156   2189.753662                          0.0
# 2020-01-31 21:15:27  70.918228   2168.441406                          0.0
# 2020-01-31 21:15:42  70.889786   2167.139893                          0.0
# 2020-01-31 21:16:04  70.795486   2177.359375                          0.0
# 2020-01-31 21:16:19  70.758934   2198.479736                          0.0
#
#                      k100_pue  cep_cooling_tower_tons  \
# timestamp_utc
# 2020-01-31 21:15:04  1.273945                     0.0
# 2020-01-31 21:15:27  1.275543                     0.0
# 2020-01-31 21:15:42  1.278681                     0.0
# 2020-01-31 21:16:04  1.272979                     0.0
# 2020-01-31 21:16:19  1.271757                     0.0
#
#                      cep_outside_air_dry_bulb_temp  \
# timestamp_utc
# 2020-01-31 21:15:04                      52.443222
# 2020-01-31 21:15:27                      52.457367
# 2020-01-31 21:15:42                      52.482094
# 2020-01-31 21:16:04                      52.460892
# 2020-01-31 21:16:19                      52.450294
#
#                      cep_outside_air_dew_point_temp  cep_make_up_flow  \
# timestamp_utc
# 2020-01-31 21:15:04                       37.895134               0.0
# 2020-01-31 21:15:27                       37.797230               0.0
# 2020-01-31 21:15:42                       37.766548               0.0
# 2020-01-31 21:16:04                       37.801796               0.0
# 2020-01-31 21:16:19                       37.868530               0.0
#
#                      cep_outside_air_wet_bulb_temp  k100_space_temp_4  ...  \
# timestamp_utc                                                          ...
# 2020-01-31 21:15:04                      45.458000          74.785332  ...
# 2020-01-31 21:15:27                      45.426201          74.795929  ...
# 2020-01-31 21:15:42                      45.426201          74.789574  ...
# 2020-01-31 21:16:04                      45.429733          74.776855  ...
# 2020-01-31 21:16:19                      45.450928          74.768387  ...
#
#                      almepo_shutdown_alarm  cep_outside_air_rh  \
# timestamp_utc
# 2020-01-31 21:15:04                    0.0           57.482128
# 2020-01-31 21:15:27                    0.0           57.231300
# 2020-01-31 21:15:42                    0.0           57.110207
# 2020-01-31 21:16:04                    0.0           57.234161
# 2020-01-31 21:16:19                    0.0           57.407043
#
#                      almmtw_makeup_emergency_shutdown_alarm  k100_total_power  \
# timestamp_utc
# 2020-01-31 21:15:04                                     0.0       5696.724121
# 2020-01-31 21:15:27                                     0.0       5713.435547
# 2020-01-31 21:15:42                                     0.0       5700.886230
# 2020-01-31 21:16:04                                     0.0       5668.766602
# 2020-01-31 21:16:19                                     0.0       5619.274902
#
#                      cep_kw_per_ton       mtwflw  k100_space_temp_1  \
# timestamp_utc
# 2020-01-31 21:15:04        0.712855  4343.891602          77.330818
# 2020-01-31 21:15:27        0.726013  4312.183105          77.330818
# 2020-01-31 21:15:42        0.734211  4293.492188          77.320221
# 2020-01-31 21:16:04        0.710725  4285.313965          77.296921
# 2020-01-31 21:16:19        0.694345  4318.357422          77.294800
#
#                      ct_water_flowrate  k100_space_temp_3      mtwrt
# timestamp_utc
# 2020-01-31 21:15:04                0.0          75.376144  83.008545
# 2020-01-31 21:15:27                0.0          75.348602  83.001266
# 2020-01-31 21:15:42                0.0          75.329529  83.002884
# 2020-01-31 21:16:04                0.0          75.295624  82.990372
# 2020-01-31 21:16:19                0.0          75.280792  82.981873
#
# [5 rows x 24 columns]

# %%
cooling_df.tail(5)
# Out:
#                          mtwst  cep_mtw_tons  almk100_leakdetection_alarm  \
# timestamp_utc
# 2021-01-25 22:29:39  69.146515   2103.173340                          0.0
# 2021-01-25 22:29:50  69.144089   2126.177979                          0.0
# 2021-01-25 22:30:02  69.148254   2110.370850                          0.0
# 2021-01-25 22:30:19  69.154816   2114.762451                          0.0
# 2021-01-25 22:30:41  69.160446   2111.573975                          0.0
#
#                      k100_pue  cep_cooling_tower_tons  \
# timestamp_utc
# 2021-01-25 22:29:39  1.032464             2250.517578
# 2021-01-25 22:29:50  1.033352             2250.417725
# 2021-01-25 22:30:02  1.033511             2251.145508
# 2021-01-25 22:30:19  1.033763             2251.205322
# 2021-01-25 22:30:41  1.032403             2250.063721
#
#                      cep_outside_air_dry_bulb_temp  \
# timestamp_utc
# 2021-01-25 22:29:39                      47.553215
# 2021-01-25 22:29:50                      47.507286
# 2021-01-25 22:30:02                      47.496681
# 2021-01-25 22:30:19                      47.489624
# 2021-01-25 22:30:41                      47.482552
#
#                      cep_outside_air_dew_point_temp  cep_make_up_flow  \
# timestamp_utc
# 2021-01-25 22:29:39                       46.926910         41.599998
# 2021-01-25 22:29:50                       46.873745         42.133335
# 2021-01-25 22:30:02                       46.869823         43.733334
# 2021-01-25 22:30:19                       46.950890         40.533333
# 2021-01-25 22:30:41                       46.930199         28.533333
#
#                      cep_outside_air_wet_bulb_temp  k100_space_temp_4  ...  \
# timestamp_utc                                                          ...
# 2021-01-25 22:29:39                      47.224625          72.036957  ...
# 2021-01-25 22:29:50                      47.175163          72.022125  ...
# 2021-01-25 22:30:02                      47.168091          72.041199  ...
# 2021-01-25 22:30:19                      47.206963          72.020012  ...
# 2021-01-25 22:30:41                      47.192825          72.032730  ...
#
#                      almepo_shutdown_alarm  cep_outside_air_rh  \
# timestamp_utc
# 2021-01-25 22:29:39                    0.0           97.666855
# 2021-01-25 22:29:50                    0.0           97.639709
# 2021-01-25 22:30:02                    0.0           97.664246
# 2021-01-25 22:30:19                    0.0           97.989616
# 2021-01-25 22:30:41                    0.0           97.939194
#
#                      almmtw_makeup_emergency_shutdown_alarm  k100_total_power  \
# timestamp_utc
# 2021-01-25 22:29:39                                     0.0       5156.959473
# 2021-01-25 22:29:50                                     0.0       5140.075195
# 2021-01-25 22:30:02                                     0.0       5075.697266
# 2021-01-25 22:30:19                                     0.0       5100.565430
# 2021-01-25 22:30:41                                     0.0       5194.798828
#
#                      cep_kw_per_ton       mtwflw  k100_space_temp_1  \
# timestamp_utc
# 2021-01-25 22:29:39        0.099998  5380.755859          75.426178
# 2021-01-25 22:29:50        0.100272  5430.487793          75.430412
# 2021-01-25 22:30:02        0.101781  5389.935059          75.430412
# 2021-01-25 22:30:19        0.102037  5396.777344          75.434654
# 2021-01-25 22:30:41        0.100197  5375.916016          75.447357
#
#                      ct_water_flowrate  k100_space_temp_3      mtwrt
# timestamp_utc
# 2021-01-25 22:29:39        3298.677246          72.644737  78.525208
# 2021-01-25 22:29:50        3298.677246          72.655334  78.542755
# 2021-01-25 22:30:02        3298.677246          72.644737  78.545715
# 2021-01-25 22:30:19        3298.677246          72.646851  78.558792
# 2021-01-25 22:30:41        3298.892822          72.629898  78.578323
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Splitting timestamp for groupings

# %%
cooling_df['Year'] = cooling_df.index.year
cooling_df['Month'] = cooling_df.index.month
cooling_df['Week'] = cooling_df.index.week
cooling_df['Day'] = cooling_df.index.day

cooling_df.head(5)
# Out:
# <ipython-input-18-ffcfa5b7ee4f>:3: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   cooling_df['Week'] = cooling_df.index.week
#                          mtwst  cep_mtw_tons  almk100_leakdetection_alarm  \
# timestamp_utc
# 2020-01-31 21:15:04  70.910156   2189.753662                          0.0
# 2020-01-31 21:15:27  70.918228   2168.441406                          0.0
# 2020-01-31 21:15:42  70.889786   2167.139893                          0.0
# 2020-01-31 21:16:04  70.795486   2177.359375                          0.0
# 2020-01-31 21:16:19  70.758934   2198.479736                          0.0
#
#                      k100_pue  cep_cooling_tower_tons  \
# timestamp_utc
# 2020-01-31 21:15:04  1.273945                     0.0
# 2020-01-31 21:15:27  1.275543                     0.0
# 2020-01-31 21:15:42  1.278681                     0.0
# 2020-01-31 21:16:04  1.272979                     0.0
# 2020-01-31 21:16:19  1.271757                     0.0
#
#                      cep_outside_air_dry_bulb_temp  \
# timestamp_utc
# 2020-01-31 21:15:04                      52.443222
# 2020-01-31 21:15:27                      52.457367
# 2020-01-31 21:15:42                      52.482094
# 2020-01-31 21:16:04                      52.460892
# 2020-01-31 21:16:19                      52.450294
#
#                      cep_outside_air_dew_point_temp  cep_make_up_flow  \
# timestamp_utc
# 2020-01-31 21:15:04                       37.895134               0.0
# 2020-01-31 21:15:27                       37.797230               0.0
# 2020-01-31 21:15:42                       37.766548               0.0
# 2020-01-31 21:16:04                       37.801796               0.0
# 2020-01-31 21:16:19                       37.868530               0.0
#
#                      cep_outside_air_wet_bulb_temp  k100_space_temp_4  ...  \
# timestamp_utc                                                          ...
# 2020-01-31 21:15:04                      45.458000          74.785332  ...
# 2020-01-31 21:15:27                      45.426201          74.795929  ...
# 2020-01-31 21:15:42                      45.426201          74.789574  ...
# 2020-01-31 21:16:04                      45.429733          74.776855  ...
# 2020-01-31 21:16:19                      45.450928          74.768387  ...
#
#                      cep_kw_per_ton       mtwflw  k100_space_temp_1  \
# timestamp_utc
# 2020-01-31 21:15:04        0.712855  4343.891602          77.330818
# 2020-01-31 21:15:27        0.726013  4312.183105          77.330818
# 2020-01-31 21:15:42        0.734211  4293.492188          77.320221
# 2020-01-31 21:16:04        0.710725  4285.313965          77.296921
# 2020-01-31 21:16:19        0.694345  4318.357422          77.294800
#
#                      ct_water_flowrate  k100_space_temp_3      mtwrt  Year  \
# timestamp_utc
# 2020-01-31 21:15:04                0.0          75.376144  83.008545  2020
# 2020-01-31 21:15:27                0.0          75.348602  83.001266  2020
# 2020-01-31 21:15:42                0.0          75.329529  83.002884  2020
# 2020-01-31 21:16:04                0.0          75.295624  82.990372  2020
# 2020-01-31 21:16:19                0.0          75.280792  82.981873  2020
#
#                      Month  Week  Day
# timestamp_utc
# 2020-01-31 21:15:04      1     5   31
# 2020-01-31 21:15:27      1     5   31
# 2020-01-31 21:15:42      1     5   31
# 2020-01-31 21:16:04      1     5   31
# 2020-01-31 21:16:19      1     5   31
#
# [5 rows x 28 columns]

# %%
cooling_df.columns
# Out:
# Index(['mtwst', 'cep_mtw_tons', 'almk100_leakdetection_alarm', 'k100_pue',
#        'cep_cooling_tower_tons', 'cep_outside_air_dry_bulb_temp',
#        'cep_outside_air_dew_point_temp', 'cep_make_up_flow',
#        'cep_outside_air_wet_bulb_temp', 'k100_space_temp_4',
#        'k100_space_temp_2', 'mt_loop_diff_press', 'cep_chilled_water_tons',
#        'chw_flowrate', 'almepo_shutdown_alarm', 'cep_outside_air_rh',
#        'almmtw_makeup_emergency_shutdown_alarm', 'k100_total_power',
#        'cep_kw_per_ton', 'mtwflw', 'k100_space_temp_1', 'ct_water_flowrate',
#        'k100_space_temp_3', 'mtwrt', 'Year', 'Month', 'Week', 'Day'],
#       dtype='object')

# %% [markdown]
# ## Calculate maxs and mins for Total Power

# %%
week_list = sorted(cooling_df["Week"].unique())

maxs = np.zeros(len(week_list))
mins = np.zeros(len(week_list))

for idx, wk in enumerate(week_list):    
    week_df = cooling_df[cooling_df["Week"] == wk] 
    
    maxs[idx] = week_df["k100_total_power"].max()
    
    new_min = week_df["k100_total_power"].min()
    if (new_min > 0):
        mins[idx] = new_min

# %% [markdown]
# ## Convert from kW to MW

# %%
cooling_df["k100_total_power_mw"] = cooling_df["k100_total_power"] / 1000

maxs = maxs / 1000
mins = mins / 1000

# %% [markdown]
# # Seaborn publication style

# %%
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# Initialize style
plt.style.use("acm_ieee_latex_pubstyle.txt")

SINGLE_COLUMN = SINGLE_WIDTH = 8.0
DOUBLE_COLUMN = DOUBLE_WIDTH = 16.0

def width_height(width=SINGLE_COLUMN, height=None, columns=1, rows=1):
    """Width driven sizing for seaborn multi-grid layouts
    
    Derive height & aspect kwargs for facetgrid, pairgrid & friends with a target sizing
    in terms of width and height.  Convenient for creating figures that has
    to be fit into a certain width, while maintaining the correct aspect ratios of the fonts.
    Call this function to derive the height & aspect
    
    Currently, ACM & IEEE latex, single column figure defaults to a width of 8inch
    and the double column figure defaults to a width of 8 inch for the correct text scaling
    
    Usage:
    - sns.FacetGrid( ... , **width_height())

    :param width: target width in inches (4 inch for a single column figure is default)
    :param height: target heigth in inches (width * 3/4 - golden ratio is the default)
    :param columns: target # of columns for facetgrid
    :param rows: target # of rows for facetgrid
    """
    if height is None:
        height = width * 3/4
    ratio = float(width) / (float(height) / float(rows))
    return {"height": (float(width) / ratio), "aspect": ratio / float(columns)}

# %% [markdown]
# # Plot

# %%
plt.close()

# Override acm-ieee-latex-pubstyle
plt.figure(figsize=(8,6))
sns.despine(top=False, right=False)
sns.set_context(rc = {'patch.linewidth': 0.0, 'axes.labelsize': 12})

# Layout
gs = mpl.gridspec.GridSpec(5, 1, height_ratios=[2, 1, 1, 1, 1]) 
gs.update(hspace=0.2)

ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1], sharex=ax0)
ax2 = plt.subplot(gs[2], sharex=ax0)
ax3 = plt.subplot(gs[3], sharex=ax0)
ax4 = plt.subplot(gs[4], sharex=ax0)

plt.setp(ax0.get_xticklabels(), visible=False)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=False)


# Power plot with maxs and mins
sns.scatterplot(x=week_list, y=maxs, marker="^", color="r", ax=ax0)
sns.boxplot(data=cooling_df, x='Week', y='k100_total_power_mw', showfliers=False, ax=ax0, linewidth=1)
ax0.set_ylabel("Power (MW)")
ax0.set(xlabel=None)
ax0.set_ylim([2, 13])
ax0.set_yticks([2.5, 5, 7.5, 10, 12.5])
    
# PUE plot
sns.boxplot(data=cooling_df, x='Week',y='k100_pue', showfliers=False, ax=ax1, linewidth=1)
ax1.set_ylabel("PUE")
ax1.set(xlabel=None)
ax1.set_ylim([0.95, 1.6])
ax1.set_yticks([1.0, 1.25, 1.5])

# Wet Bulb Temp plot
sns.boxplot(data=cooling_df, x='Week',y='cep_outside_air_wet_bulb_temp', showfliers=False, ax=ax2, linewidth=1)
ax2.set_ylabel("Wetbulb\nTemp (F)")
ax2.set(xlabel=None)
ax2.set_ylim([20, 100])
ax2.set_yticks([25, 50, 75, 100])

# CEP Supply Tonage plot
sns.boxplot(data=cooling_df, x='Week',y='cep_mtw_tons', showfliers=False, ax=ax3, linewidth=1)
ax3.set_ylabel("Cooling\n(Tons)")
ax3.set(xlabel=None)
ax3.set_ylim([1000, 3500])
ax3.set_yticks([1000, 2000, 3000])

# CEP Chilled Water Tonage plot
sns.boxplot(data=cooling_df, x='Week',y='cep_chilled_water_tons', showfliers=False, ax=ax4, linewidth=1)
ax4.set_ylabel("Trim\n(Tons)")
ax4.set_ylim([0, 2900])
ax4.set_yticks([0, 1000, 2000])

# Prepare x-axis for all 5 plots
ax4.set_xlim(0, 53, 10)
ax4.set_xlabel("")

my_xticks = [1, 4.5, 8.5, 12, 16, 20.5, 25, 29.5, 34, 38, 42.5, 47]
my_xtick_labels= ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec"] 

plt.xticks(my_xticks, my_xtick_labels)

for item in ax4.get_xticklabels():
    item.set_rotation(50)

plt.subplots_adjust(hspace=.0)
plt.savefig("input_power_total_energy_scatter.pdf", format="pdf", bbox_inches='tight', pad_inches=0.01)
plt.show()
